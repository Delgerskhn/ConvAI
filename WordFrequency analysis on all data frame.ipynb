# %% [markdown]
# Goal
#     Make analysis on words

# %%
import import_ipynb
import prepareDataFrame
# Out:
# importing Jupyter notebook from prepareDataFrame.ipynb

# %%
personaCountDF = prepareDataFrame.personadf["persona"].value_counts().reset_index()
personaCountDF.rename(columns={'index': 'persona', 'persona': 'count'}, inplace=True)
personaCountDF.hist( bins=10, edgecolor="black")
# Out:
#                                                 persona  count
# 0                            my favorite color is blue.    225
# 1                            my favorite food is pizza.    168
# 2                                         i am a vegan.    116
# 3                                       i love animals.    110
# 4                                       i like to read.    109
# ...                                                 ...    ...
# 6092   i'm a night owl , but i'm an introvert so i d...      1
# 6093           i don't think my girlfriend understands.      1
# 6094   sometimes i feel like i've already been throu...      1
# 6095   i do not really like vegetables or fruit but ...      1
# 6096           i drive a honda that's seen better days.      1
#
# [6097 rows x 2 columns]

# %%
import wordAnalyze

# %%
analyzedPersonaWordsObj = wordAnalyze.wordFreqAnalyze(prepareDataFrame.personadf, "persona")
analyzedPersonaWordsObj["df"]
# Out:
#             word  count
# 0              i  44321
# 1           like   6608
# 2             to  12747
# 3        remodel     15
# 4         homes.     41
# ...          ...    ...
# 4669  tickleback      3
# 4670    concert.      7
# 4671     they're      2
# 4672  nickleback      4
# 4673      genii.      4
#
# [4674 rows x 2 columns]

# %%
analyzedBuddy1WordsObj = wordAnalyze.wordFreqAnalyze(prepareDataFrame.chatdf, "buddy1")
analyzedBuddy1WordsObj["df"]
# Out:
#              word  count
# 0              hi   3888
# 1               ,  28131
# 2             how   8815
# 3             are  13258
# 4             you  35014
# ...           ...    ...
# 16328         828      1
# 16329  concussion      1
# 16330  volkswagon      1
# 16331    moonroof      1
# 16332       muddy      1
#
# [16333 rows x 2 columns]

# %%
analyzedBuddy2WordsObj = wordAnalyze.wordFreqAnalyze(prepareDataFrame.chatdf, "buddy2")
analyzedBuddy2WordsObj["histogram"]
# Out:
#               word  count
# 0              you  35500
# 1             must    673
# 2               be   4264
# 3             very   2258
# 4             fast    274
# ...            ...    ...
# 16821      keepers      1
# 16822   motivators      1
# 16823  carbonation      1
# 16824       pimple      1
# 16825       popper      1
#
# [16826 rows x 2 columns]

# %%
analyzedAnswerWordsObj = wordAnalyze.wordFreqAnalyze(prepareDataFrame.answerdf, "answer")
analyzedAnswerWordsObj["df"]
# Out:
#              word   count
# 0              my  404947
# 1             mom   21070
# 2             was   64464
# 3          single    5769
# 4            with  109220
# ...           ...     ...
# 24462   herself\n       1
# 24463  minerals\n       1
# 24464        27\n       1
# 24465     bongo\n       1
# 24466    swords\n       1
#
# [24467 rows x 2 columns]

# %%
# Out:
#          conv_id  chat_id   ans_id  \
# 0              1        1        1
# 1              1        1        2
# 2              1        1        3
# 3              1        1        4
# 4              1        1        5
# ...          ...      ...      ...
# 1973986    13414    98700  1973987
# 1973987    13414    98700  1973988
# 1973988    13414    98700  1973989
# 1973989    13414    98700  1973990
# 1973990    13414    98700  1973991
#
#                                                     answer
# 0        my mom was single with 3 boys , so we never le...
# 1        i try to wear all black every day . it makes m...
# 2        well nursing stresses you out so i wish luck w...
# 3            yeah just want to pick up nba nfl getting old
# 4             i really like celine dion . what about you ?
# ...                                                    ...
# 1973986                        oh . do you have any pets ?
# 1973987                                     ho ho ho ho ho
# ...
